# %%
# Use historical offensive MLB data by player to predict individual player OPS for 2021.
# Using OPS to Salary to measure value of a player, make a team roster of the best value players

# %%
## Data preparation
# 1. Rolling annual window
# 80% training data 30% testing data
# 3. Use MinMaxScaler to X and y values

# %%
# Imports

import os
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
from pathlib import Path

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
import glob

# %%
# Load player stats

path = '../Resources/batting_stats_*.csv'
all_files = glob.glob(path)
all_files
# Out:
# ['../Resources\\batting_stats_2010.csv',
#  '../Resources\\batting_stats_2011.csv',
#  '../Resources\\batting_stats_2012.csv',
#  '../Resources\\batting_stats_2013.csv',
#  '../Resources\\batting_stats_2014.csv',
#  '../Resources\\batting_stats_2015.csv',
#  '../Resources\\batting_stats_2016.csv',
#  '../Resources\\batting_stats_2017.csv',
#  '../Resources\\batting_stats_2018.csv',
#  '../Resources\\batting_stats_2019.csv',
#  '../Resources\\batting_stats_2020.csv',
#  '../Resources\\batting_stats_2021.csv']

# %%
# Turn into dataframe
data = []

for file in all_files:
    df = pd.read_csv(file, index_col=None, header=0)    
    year = file[-8:-4]
    df['Year'] = year
    data.append(df)

# %%
# Concatenate dataframes

stats_df = pd.concat(data, axis=0, ignore_index=True)

# %%
stats_df
# Out:
#                  Player Team Pos  Age    G   AB    R    H  2B  3B  ...  BB  \
# 0         Ichiro Suzuki  SEA  OF   47  162  680   74  214  30   3  ...  45
# 1           Derek Jeter  NYY  SS   47  157  663  111  179  30   3  ...  63
# 2         Michael Young  TEX  3B   44  157  656   99  186  36   3  ...  50
# 3           Juan Pierre  CWS  OF   43  160  651   96  179  18   3  ...  45
# 4          Rickie Weeks  MIL  DH   38  160  651  112  175  32   4  ...  76
# 5         Marco Scutaro  BOS  2B   45  150  632   92  174  38   0  ...  53
# 6         Nick Markakis  BAL  OF   37  160  629   79  187  45   3  ...  73
# 7           Denard Span  MIN  OF   37  153  629   85  166  24  10  ...  60
# 8      Brandon Phillips  CIN  2B   40  155  626  100  172  33   5  ...  46
# 9         Robinson Cano  NYY  2B   38  160  626  103  200  41   3  ...  57
# 10           Ryan Braun  MIL  OF   37  157  619  101  188  45   1  ...  56
# 11       Austin Jackson  DET  OF   34  151  618  103  181  34  10  ...  47
# 12       Howie Kendrick  LAA  DH   38  158  616   67  172  41   4  ...  28
# 13         Hunter Pence  HOU  OF   38  156  614   93  173  29   3  ...  41
# 14        Chase Headley   SD  3B   37  161  610   77  161  29   3  ...  56
# 15        Casey McGehee  MIL  3B   38  157  610   70  174  38   1  ...  50
# 16      Michael Cuddyer  MIN  OF   42  157  609   93  165  37   5  ...  58
# 17           Carlos Lee  HOU  1B   45  157  605   67  149  29   1  ...  37
# 18        Chone Figgins  SEA  OF   43  161  602   62  156  21   2  ...  74
# 19            Matt Kemp  LAD  DH   36  162  602   82  150  25   6  ...  53
# 20        Mark Teixeira  NYY  1B   41  158  601  113  154  36   0  ...  93
# 21        Carl Crawford   TB  OF   39  154  600  110  184  30  13  ...  46
# 22         Martin Prado  ATL  3B   37  140  599  100  184  40   3  ...  40
# 23        Matt Holliday  STL  OF   41  158  596   95  186  45   1  ...  69
# 24         Billy Butler   KC  1B   35  158  595   77  189  45   0  ...  69
# 25           Jose Lopez  SEA  3B   37  150  593   49  142  29   0  ...  23
# 26    Vladimir Guerrero  TEX  DH   46  152  593   83  178  27   1  ...  35
# 27        Garrett Jones  PIT  1B   40  158  592   64  146  34   1  ...  53
# 28      Adrian Gonzalez   SD  1B   39  160  591   87  176  33   0  ...  93
# 29         Vernon Wells  TOR  OF   42  157  590   79  161  44   3  ...  50
# ...                 ...  ...  ..  ...  ...  ...  ...  ...  ..  ..  ...  ..
# 8062      John Andreoli   SD  OF   31    7    6    2    1   1   0  ...   1
# 8063        Tyler Nevin  BAL  1B   24    2    5    0    1   1   0  ...   1
# 8064      Ronnie Dawson  HOU  OF   26    3    5    2    1   0   0  ...   1
# 8065    Emmanuel Rivera   KC  3B   25    2    5    0    2   0   0  ...   0
# 8066        Scott Hurst  STL  OF   25    7    5    0    0   0   0  ...   0
# 8067       Luis Barrera  OAK  OF   25    4    5    0    1   0   0  ...   0
# 8068    Jonathan Lucroy  ATL   C   35    2    5    2    1   0   0  ...   3
# 8069        Hunter Owen  PIT  3B   27    3    4    0    0   0   0  ...   0
# 8070       Curtis Terry  TEX  1B   24    1    4    0    0   0   0  ...   0
# 8071        Nelson Cruz   TB  DH   41    1    4    2    1   0   0  ...   1
# 8072      Trey Amburgey  NYY  OF   26    2    4    0    0   0   0  ...   0
# 8073      Braden Bishop  SEA  OF   27    8    4    1    1   0   0  ...   0
# 8074        Kevan Smith   TB   C   33    3    4    2    1   0   0  ...   0
# 8075      Taylor Gushue  CHC   C   27    2    4    0    0   0   0  ...   0
# 8076   Patrick Kivlehan   SD  3B   31    5    4    3    1   0   0  ...   2
# 8077      Deven Marrero  MIA  SS   30    1    3    0    0   0   0  ...   0
# 8078   Humberto Arteaga  WAS  SS   27    1    3    0    0   0   0  ...   0
# 8079       Jared Hoying  TOR  OF   32    2    3    0    0   0   0  ...   0
# 8080        Ali Sanchez  STL   C   24    1    3    0    1   1   0  ...   0
# 8081      Ivan Castillo   SD  2B   26    3    3    0    1   0   0  ...   1
# 8082        Sean Kazmar  ATL  SS   36    3    2    0    0   0   0  ...   0
# 8083          Corey Ray  MIL  OF   26    1    2    1    0   0   0  ...   1
# 8084           Joe Odom   TB   C   29    2    2    0    0   0   0  ...   0
# 8085     Breyvic Valera  TOR  2B   29    2    2    0    0   0   0  ...   0
# 8086       Jakson Reetz  WAS   C   25    2    2    1    1   1   0  ...   0
# 8087           Hoy Park  NYY  SS   25    1    1    0    0   0   0  ...   0
# 8088     Carter Kieboom  WAS  3B   23    2    1    0    0   0   0  ...   1
# 8089          Skye Bolt   SF  OF   27    2    1    0    0   0   0  ...   0
# 8090        Cody Wilson  WAS  OF   25    1    1    0    0   0   0  ...   0
# 8091    Mario Feliciano  MIL   C   22    1    0    1    0   0   0  ...   1
#
#        SO  SH  SF  HBP    AVG    OBP    SLG    OPS  Year
# 0      86   3   1    3  0.315  0.359  0.394  0.753  2010
# 1     106   1   3    9  0.270  0.340  0.370  0.710  2010
# 2     115   0  11    1  0.284  0.330  0.444  0.774  2010
# 3      47  15   2   21  0.275  0.341  0.316  0.657  2010
# 4     184   0   2   25  0.269  0.366  0.464  0.830  2010
# 5      71   4   3    3  0.275  0.333  0.388  0.721  2010
# 6      93   0   5    2  0.297  0.370  0.436  0.806  2010
# 7      74  10   2    4  0.264  0.331  0.348  0.679  2010
# 8      83   6   1    8  0.275  0.332  0.430  0.762  2010
# 9      77   0   5    8  0.319  0.381  0.534  0.915  2010
# 10    105   0   3    6  0.304  0.365  0.501  0.866  2010
# 11    170   3   3    4  0.293  0.345  0.400  0.745  2010
# 12     94   4   5    5  0.279  0.313  0.407  0.720  2010
# 13    105   0   3    0  0.282  0.325  0.461  0.786  2010
# 14    139   1   4    3  0.264  0.327  0.375  0.702  2010
# 15    102   0   8    2  0.285  0.337  0.464  0.801  2010
# 16     93   0   4    4  0.271  0.336  0.417  0.753  2010
# 17     59   0   4    3  0.246  0.291  0.417  0.708  2010
# 18    114  17   6    3  0.259  0.340  0.306  0.646  2010
# 19    170   0   9    4  0.249  0.310  0.450  0.760  2010
# 20    122   0   5   13  0.256  0.365  0.481  0.846  2010
# 21    104   3   5    3  0.307  0.356  0.495  0.851  2010
# 22     86   3   6    3  0.307  0.350  0.459  0.809  2010
# 23     93   0   2    8  0.312  0.390  0.532  0.922  2010
# 24     78   0   9    5  0.318  0.388  0.469  0.857  2010
# 25     66   0   3    3  0.239  0.270  0.339  0.609  2010
# 26     60   0   6    9  0.300  0.345  0.496  0.841  2010
# 27    123   0   8    1  0.247  0.306  0.414  0.720  2010
# 28    114   2   4    2  0.298  0.393  0.511  0.904  2010
# 29     84   0   3    3  0.273  0.331  0.515  0.846  2010
# ...   ...  ..  ..  ...    ...    ...    ...    ...   ...
# 8062    3   0   0    0  0.167  0.286  0.333  0.619  2021
# 8063    2   0   0    0  0.200  0.333  0.400  0.733  2021
# 8064    0   0   0    0  0.200  0.333  0.200  0.533  2021
# 8065    1   0   0    0  0.400  0.400  0.400  0.800  2021
# 8066    1   0   0    0  0.000  0.000  0.000  0.000  2021
# 8067    2   0   0    0  0.200  0.200  0.200  0.400  2021
# 8068    2   1   0    0  0.200  0.500  0.200  0.700  2021
# 8069    3   0   0    1  0.000  0.200  0.000  0.200  2021
# 8070    2   0   0    0  0.000  0.000  0.000  0.000  2021
# 8071    1   0   0    0  0.250  0.400  1.000  1.400  2021
# 8072    2   0   0    0  0.000  0.000  0.000  0.000  2021
# 8073    2   1   0    0  0.250  0.250  0.250  0.500  2021
# 8074    2   0   0    0  0.250  0.250  0.250  0.500  2021
# 8075    3   0   0    0  0.000  0.000  0.000  0.000  2021
# 8076    3   0   1    1  0.250  0.500  0.250  0.750  2021
# 8077    0   0   0    0  0.000  0.000  0.000  0.000  2021
# 8078    0   0   1    0  0.000  0.000  0.000  0.000  2021
# 8079    1   0   0    0  0.000  0.000  0.000  0.000  2021
# 8080    0   0   0    0  0.333  0.333  0.667  1.000  2021
# 8081    0   0   0    0  0.333  0.500  0.333  0.833  2021
# 8082    0   0   0    0  0.000  0.000  0.000  0.000  2021
# 8083    1   0   0    0  0.000  0.333  0.000  0.333  2021
# 8084    1   0   0    0  0.000  0.000  0.000  0.000  2021
# 8085    2   0   0    0  0.000  0.000  0.000  0.000  2021
# 8086    0   0   0    0  0.500  0.500  1.000  1.500  2021
# 8087    0   0   0    0  0.000  0.000  0.000  0.000  2021
# 8088    1   0   0    0  0.000  0.500  0.000  0.500  2021
# 8089    1   0   0    0  0.000  0.000  0.000  0.000  2021
# 8090    0   0   0    0  0.000  0.000  0.000  0.000  2021
# 8091    0   0   0    0  0.000  1.000  0.000  1.000  2021
#
# [8092 rows x 24 columns]

# %%
# Show columns

stats_df.columns
# Out:
# Index(['Player', 'Team', 'Pos', 'Age', 'G', 'AB', 'R', 'H', '2B', '3B', 'HR',
#        'RBI', 'SB', 'CS', 'BB', 'SO', 'SH', 'SF', 'HBP', 'AVG', 'OBP', 'SLG',
#        'OPS', 'Year'],
#       dtype='object')

# %%
# Select relevant columns

stats_df = stats_df[['Year', 'Player', 'Team', 'Pos', 'Age', 'G', 'AB', 'AVG', 'OBP', 'SLG','OPS']]
stats_df.head()
# Out:
#    Year         Player Team Pos  Age    G   AB    AVG    OBP    SLG    OPS
# 0  2010  Ichiro Suzuki  SEA  OF   47  162  680  0.315  0.359  0.394  0.753
# 1  2010    Derek Jeter  NYY  SS   47  157  663  0.270  0.340  0.370  0.710
# 2  2010  Michael Young  TEX  3B   44  157  656  0.284  0.330  0.444  0.774
# 3  2010    Juan Pierre  CWS  OF   43  160  651  0.275  0.341  0.316  0.657
# 4  2010   Rickie Weeks  MIL  DH   38  160  651  0.269  0.366  0.464  0.830

# %%
# Roster positions - we need to find the best OPS for salary value per player

# 1 (pitcher) = P
# 2 (catcher) = C
# 3 (first baseman) = 1B
# 4 (second baseman) = 2B
# 5 (third baseman) = 3B
# 6 (shortstop) = SS
# 7 (left fielder) = LF
# 8 (center fielder) = CF
# 9 (right fielder) = RF

# %%
# Below function takes column number for the features (X) and target (y)
# It accumulates the data with a rolling window of X(t-n) to predict Xt
# Finally, it returns a numpy array of X and y

def window_data(df, window, feature_col_number, target_col_number):
    X = []
    y = []
    print(len(df) - window - 1)
    for i in range(len(df) - window - 1):
        features = df.iloc[i:(i + window), feature_col_number]
        target = df.iloc[(i + window), target_col_number]
        X.append(features)
        y.append(target)
    return np.array(X), np.array(y).reshape(-1, 1)

# %%
# Predict Closing Prices using a 10 day window of previous closing prices

window_size = 1

# Column index 0 is the 'index' column
# Column index 1 is the 'stock' column
feature_column = 0
target_column = 1
X, y = window_data(df, window_size, feature_column, target_column)
