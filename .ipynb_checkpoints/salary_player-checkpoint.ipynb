# %%
# Initial imports
import os
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
from pathlib import Path
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\Andy L\anaconda3\envs\dev\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
# Reading moneyball and salary data
file_path = Path("./Resources/Result/Moneyball.csv")
file_path_salary = Path("./Resources/2021 MLB Salary Combined.csv")

moneyball_df = pd.read_csv(file_path, index_col = 0)
salary_df = pd.read_csv(file_path_salary, index_col = 0)

moneyball_df.head(20)
# Out:
#                         Real  Predicted
# Player
# AJ Pollock          0.642333   0.784162
# AJ Reed             0.696000   0.807914
# Aaron Altherr       0.757000   0.823085
# Aaron Hicks         0.586000   0.775682
# Aaron Judge         0.637000   0.791791
# Abiatal Avelino     0.546000   0.784224
# Abraham Almonte     0.637333   0.794459
# Abraham Toro        0.802667   0.822177
# Adalberto Mondesi   0.845333   0.831775
# Adam Duvall         0.712000   0.804174
# Adam Eaton          0.598250   0.795513
# Adam Engel          0.614667   0.792148
# Adam Frazier        0.819333   0.825502
# Adam Haseley        0.659333   0.802499
# Adam Jones          0.694000   0.838240
# Adam Moore          0.790000   0.816960
# Adam Rosales        0.614000   0.783100
# Addison Russell     0.889000   0.849534
# Adeiny Hechavarria  0.727667   0.811012
# Adolis Garcia       1.401667   0.845935

# %%
salary_df.head()
# Out:
#                     Age Position Status  Wavier Option  Base Salary  \
# Player
# Madison Bumgarner    31       SP    Vet            NaN     19000000
# Nick Ahmed           31       SS    Vet            NaN      7500000
# Kole Calhoun         33       RF    Vet            NaN      8000000
# Eduardo Escobar      32       3B    Vet            NaN      7500000
# David Peralta        33       LF    Vet            NaN      7500000
#
#                     Signing Bonus  Payroll Salary  Adjusted Salary  Payroll %  \
# Player
# Madison Bumgarner               0        19000000         14000000      15.16
# Nick Ahmed                 375000         8125000          8125000       8.80
# Kole Calhoun                    0         8000000          8000000       8.67
# Eduardo Escobar            166668         7666668          7666668       8.30
# David Peralta                   0         7500000          7500000       8.12
#
#                     Luxury Tax Salary                  Team Injured
# Player
# Madison Bumgarner            17000000  Arizona Diamondbacks     NaN
# Nick Ahmed                    8125000  Arizona Diamondbacks     NaN
# Kole Calhoun                  8000000  Arizona Diamondbacks     NaN
# Eduardo Escobar               7000000  Arizona Diamondbacks     NaN
# David Peralta                 7333333  Arizona Diamondbacks     NaN

# %%
salary_df = salary_df.drop(columns = ['Age','Status','Wavier Option', 'Base Salary', 'Signing Bonus', 'Adjusted Salary', 'Payroll %', 'Luxury Tax Salary', 'Injured'])
salary_df.head()
# Out:
#                    Position  Payroll Salary                  Team
# Player
# Madison Bumgarner        SP        19000000  Arizona Diamondbacks
# Nick Ahmed               SS         8125000  Arizona Diamondbacks
# Kole Calhoun             RF         8000000  Arizona Diamondbacks
# Eduardo Escobar          3B         7666668  Arizona Diamondbacks
# David Peralta            LF         7500000  Arizona Diamondbacks

# %%
combined_df = pd.concat([moneyball_df, salary_df], axis="columns", join="inner")
combined_df.head(20)
# Out:
#                        Real  Predicted Position  Payroll Salary  \
# Player
# Aaron Hicks        0.586000   0.775682       CF        10785714
# Aaron Judge        0.637000   0.791791       RF        10175000
# Abraham Almonte    0.637333   0.794459       CF          990000
# Adalberto Mondesi  0.845333   0.831775       SS         2525000
# Adam Duvall        0.712000   0.804174       RF         2000000
# Adam Eaton         0.598250   0.795513       RF          570500
# Adam Engel         0.614667   0.792148       LF         1375000
# Adam Frazier       0.819333   0.825502       2B         4300000
# Albert Pujols      0.624750   0.790017       DH          570500
# Aledmys Diaz       0.721667   0.797191       SS         3000000
# Alex Avila         0.716000   0.805330        C         1500000
# Alex Blandino      0.797000   0.822388       3B          573000
# Alex Bregman       0.503667   0.771929       3B        12666666
# Alex Dickerson     0.782500   0.819060       LF         2100000
# Alex Kirilloff     0.361000   0.752217       DH          570500
# Amed Rosario       0.521000   0.757168       SS         2400000
# Andrelton Simmons  0.587333   0.788407       SS        10500000
# Andrew Benintendi  0.693333   0.800641       LF         6600000
# Andrew Knapp       0.760333   0.811550        C         1100000
# Andrew McCutchen   0.749333   0.804123       LF        20000000
#
#                                     Team
# Player
# Aaron Hicks             New York Yankees
# Aaron Judge             New York Yankees
# Abraham Almonte           Atlanta Braves
# Adalberto Mondesi     Kansas City Royals
# Adam Duvall                Miami Marlins
# Adam Eaton            Los Angeles Angels
# Adam Engel             Chicago White Sox
# Adam Frazier          Pittsburgh Pirates
# Albert Pujols        Los Angeles Dodgers
# Aledmys Diaz              Houston Astros
# Alex Avila          Washington Nationals
# Alex Blandino            Cincinnati Reds
# Alex Bregman              Houston Astros
# Alex Dickerson      San Francisco Giants
# Alex Kirilloff           Minnesota Twins
# Amed Rosario           Cleveland Indians
# Andrelton Simmons        Minnesota Twins
# Andrew Benintendi     Kansas City Royals
# Andrew Knapp       Philadelphia Phillies
# Andrew McCutchen   Philadelphia Phillies

# %%
expanded_moneyball_df = combined_df
expanded_moneyball_df['OPS Per Millionth Dollar'] = expanded_moneyball_df['Predicted'] / expanded_moneyball_df['Payroll Salary'] * 1000000
expanded_moneyball_df.to_csv(r'expanded moneyball.csv')
expanded_moneyball_df.head(20)
# Out:
#                        Real  Predicted Position  Payroll Salary  \
# Player
# Aaron Hicks        0.586000   0.775682       CF        10785714
# Aaron Judge        0.637000   0.791791       RF        10175000
# Abraham Almonte    0.637333   0.794459       CF          990000
# Adalberto Mondesi  0.845333   0.831775       SS         2525000
# Adam Duvall        0.712000   0.804174       RF         2000000
# Adam Eaton         0.598250   0.795513       RF          570500
# Adam Engel         0.614667   0.792148       LF         1375000
# Adam Frazier       0.819333   0.825502       2B         4300000
# Albert Pujols      0.624750   0.790017       DH          570500
# Aledmys Diaz       0.721667   0.797191       SS         3000000
# Alex Avila         0.716000   0.805330        C         1500000
# Alex Blandino      0.797000   0.822388       3B          573000
# Alex Bregman       0.503667   0.771929       3B        12666666
# Alex Dickerson     0.782500   0.819060       LF         2100000
# Alex Kirilloff     0.361000   0.752217       DH          570500
# Amed Rosario       0.521000   0.757168       SS         2400000
# Andrelton Simmons  0.587333   0.788407       SS        10500000
# Andrew Benintendi  0.693333   0.800641       LF         6600000
# Andrew Knapp       0.760333   0.811550        C         1100000
# Andrew McCutchen   0.749333   0.804123       LF        20000000
#
#                                     Team  OPS Per Millionth Dollar
# Player
# Aaron Hicks             New York Yankees                  0.071918
# Aaron Judge             New York Yankees                  0.077817
# Abraham Almonte           Atlanta Braves                  0.802484
# Adalberto Mondesi     Kansas City Royals                  0.329416
# Adam Duvall                Miami Marlins                  0.402087
# Adam Eaton            Los Angeles Angels                  1.394413
# Adam Engel             Chicago White Sox                  0.576108
# Adam Frazier          Pittsburgh Pirates                  0.191977
# Albert Pujols        Los Angeles Dodgers                  1.384780
# Aledmys Diaz              Houston Astros                  0.265730
# Alex Avila          Washington Nationals                  0.536887
# Alex Blandino            Cincinnati Reds                  1.435232
# Alex Bregman              Houston Astros                  0.060942
# Alex Dickerson      San Francisco Giants                  0.390029
# Alex Kirilloff           Minnesota Twins                  1.318522
# Amed Rosario           Cleveland Indians                  0.315487
# Andrelton Simmons        Minnesota Twins                  0.075086
# Andrew Benintendi     Kansas City Royals                  0.121309
# Andrew Knapp       Philadelphia Phillies                  0.737773
# Andrew McCutchen   Philadelphia Phillies                  0.040206

# %%
expanded_moneyball_df['OPMD'] = expanded_moneyball_df['OPS Per Millionth Dollar']
expanded_moneyball_df = expanded_moneyball_df.drop(columns = 'OPS Per Millionth Dollar')
expanded_moneyball_df.reset_index(inplace=True)
expanded_moneyball_df = expanded_moneyball_df.sort_values(['Position', 'OPMD'], ascending=[True, False]).drop_duplicates(['Position']).reset_index(drop=True)

# %%
expanded_moneyball_df
# Out:
#            Player      Real  Predicted Position  Payroll Salary  \
# 0   Ronald Guzman  0.636667   0.790665       1B          606000
# 1      Max Moroff  0.858500   0.813580       2B          570500
# 2   Alex Blandino  0.797000   0.822388       3B          573000
# 3    P.J. Higgins  0.885000   0.835925        C          570500
# 4     Roman Quinn  0.628000   0.793175       CF          578000
# 5   Albert Pujols  0.624750   0.790017       DH          570500
# 6       Jake Cave  0.859667   0.832654       LF          597500
# 7   Jesus Sanchez  0.678500   0.801743       OF          575000
# 8    Jaylin Davis  0.777333   0.822551       RF          570500
# 9      Will Smith  0.656333   0.794905    RP/CL        13000000
# 10  Shohei Ohtani  0.699000   0.790038       SP         3000000
# 11      Gavin Lux  0.962333   0.844177       SS          580500
#
#                      Team      OPMD
# 0           Texas Rangers  1.304727
# 1     St. Louis Cardinals  1.426082
# 2         Cincinnati Reds  1.435232
# 3            Chicago Cubs  1.465250
# 4   Philadelphia Phillies  1.372276
# 5     Los Angeles Dodgers  1.384780
# 6         Minnesota Twins  1.393563
# 7           Miami Marlins  1.394335
# 8    San Francisco Giants  1.441807
# 9          Atlanta Braves  0.061147
# 10     Los Angeles Angels  0.263346
# 11    Los Angeles Dodgers  1.454224

# %%
expanded_moneyball_df.set_index('Position', inplace=True)

# %%
expanded_moneyball_df
# Out:
#                  Player      Real  Predicted  Payroll Salary  \
# Position
# 1B        Ronald Guzman  0.636667   0.790665          606000
# 2B           Max Moroff  0.858500   0.813580          570500
# 3B        Alex Blandino  0.797000   0.822388          573000
# C          P.J. Higgins  0.885000   0.835925          570500
# CF          Roman Quinn  0.628000   0.793175          578000
# DH        Albert Pujols  0.624750   0.790017          570500
# LF            Jake Cave  0.859667   0.832654          597500
# OF        Jesus Sanchez  0.678500   0.801743          575000
# RF         Jaylin Davis  0.777333   0.822551          570500
# RP/CL        Will Smith  0.656333   0.794905        13000000
# SP        Shohei Ohtani  0.699000   0.790038         3000000
# SS            Gavin Lux  0.962333   0.844177          580500
#
#                            Team      OPMD
# Position
# 1B                Texas Rangers  1.304727
# 2B          St. Louis Cardinals  1.426082
# 3B              Cincinnati Reds  1.435232
# C                  Chicago Cubs  1.465250
# CF        Philadelphia Phillies  1.372276
# DH          Los Angeles Dodgers  1.384780
# LF              Minnesota Twins  1.393563
# OF                Miami Marlins  1.394335
# RF         San Francisco Giants  1.441807
# RP/CL            Atlanta Braves  0.061147
# SP           Los Angeles Angels  0.263346
# SS          Los Angeles Dodgers  1.454224

# %%
expanded_moneyball_df.to_csv('./Resources/Result/selected_player.csv')
