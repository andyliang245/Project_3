# %% [markdown]
# # LSTM Statistic Predictor Using OPS(On-base Plus Slugging)
#
# In this notebook, we will build and train a custom LSTM RNN that uses a 12 years of batting statistics data to predict the value of OPS.
#
# ## Statistics Use In Moneyball
#
# According to Lewis (2003), Billy Beane (the inspiration of Moneyball) decided to base his drafting of position players/hitters on certain statistics. His main two statistics included `on-base percentage (OBP)` and `slugging percentage`. These two stats combined to form a new statistic called `on-base plus slugging (OPS)`.
#
# The OPS formula below:
#
#         OBP = (H + BB + HBP) / (AB + BB + HBP + SF)
#
#         SLG = (1B)+(2∗2B)+(3∗3B)+(4∗HR) / AB
#
#
# H = Hits - when the batter strikes the ball without error
#
# BB = Walks - when a pitcher throws four pitches out of the strike zone, none of which are swing at by the batter
#
# HBP = Hit by pitch - when a batter is struck by a pitched ball without swinging at it and is awarded first base
#
# AB = At bat - when a batter reaches base via fielder's choice, hit, or error (not including catcher's interference)
#
# SF = Sacrifice fly - when a batter hits a fly-ball to the outfield or foul territory that allows a runner to score
#
# 1B = Single - when batter hits the ball and reaches first base
#
# 2B = Double - when batter hits the ball and reaches second base
#
# 3B = Triple - when batter hits the ball and reaches third base
#
# HR = Home run - when batter hits the ball and circles all four bases

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import datetime
from pathlib import Path
import glob

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf

# %matplotlib inline

# %%
file_path = './Resources/stats_df.csv'
stats_df = pd.read_csv(
    file_path,
    index_col=None,
    infer_datetime_format=True,
    parse_dates=True,
)
stats_df.head()
# Out:
#    Year           Player Team Pos  Age  ...  HBP    AVG    OBP    SLG    OPS
# 0  2019  Whit Merrifield   KC  2B   32  ...    5  0.302  0.348  0.463  0.811
# 1  2019    Marcus Semien  OAK  SS   30  ...    2  0.285  0.369  0.522  0.891
# 2  2019    Rafael Devers  BOS  3B   24  ...    4  0.311  0.361  0.555  0.916
# 3  2019  Jonathan Villar  BAL  2B   30  ...    4  0.274  0.339  0.453  0.792
# 4  2019     Ozzie Albies  ATL  2B   24  ...    4  0.295  0.352  0.500  0.852
#
# [5 rows x 24 columns]

# %%
# Drop player with 0 OPS
stats_df = stats_df[stats_df.OPS !=0].set_index('Player')

# %%
stats_df.head()
# Out:
#                  Year Team Pos  Age    G  ...  HBP    AVG    OBP    SLG    OPS
# Player                                    ...
# Whit Merrifield  2019   KC  2B   32  162  ...    5  0.302  0.348  0.463  0.811
# Marcus Semien    2019  OAK  SS   30  162  ...    2  0.285  0.369  0.522  0.891
# Rafael Devers    2019  BOS  3B   24  156  ...    4  0.311  0.361  0.555  0.916
# Jonathan Villar  2019  BAL  2B   30  162  ...    4  0.274  0.339  0.453  0.792
# Ozzie Albies     2019  ATL  2B   24  160  ...    4  0.295  0.352  0.500  0.852
#
# [5 rows x 23 columns]

# %%
# Creating X & y variables
X = stats_df.iloc[:, 4:-2]
y = stats_df["OPS"].values

# %%
# Creating training, validation, and testing sets
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

X_train.shape
# Out:
# (5914, 17)

# %%
# Scale the data
scaler = StandardScaler().fit(X)
X = scaler.transform(X)

y = y.reshape(-1, 1)
scaler_y = StandardScaler().fit(y)
y = scaler_y.transform(y)

# %%
y_train.shape
# Out:
# (5914,)

# %%
#X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
#X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# Model set-up
number_input_features = 17
hidden_nodes_layer1 = 34
hidden_nodes_layer2 = 5

# %%
# Define the LSTM RNN model
model = Sequential()

# Layer 1
model.add(
    Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Layer 2
model.add(Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
model.add(Dense(1, activation="sigmoid"))

# %%
# Compile the model
model.compile(
    loss="binary_crossentropy",
    optimizer="adam",
    metrics=[
        "accuracy",
        tf.keras.metrics.TruePositives(name="tp"),
        tf.keras.metrics.TrueNegatives(name="tn"),
        tf.keras.metrics.FalsePositives(name="fp"),
        tf.keras.metrics.FalseNegatives(name="fn"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
        tf.keras.metrics.AUC(name="auc"),
    ],
)

# %%
# Training the model
batch_size = 1000
epochs = 100
training_history = model.fit(
    X_train,
    y_train,
    #validation_data=(X_val, y_val),
    epochs=epochs,
    batch_size=batch_size,
    verbose=1
)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 2s 14ms/step - loss: 13.5565 - accuracy: 0.0012 - tp: 32.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 5882.0000 - precision: 1.0000 - recall: 0.0054 - auc: 0.0000e+00
# Epoch 2/100
# 6/6 [==============================] - 0s 7ms/step - loss: 7.2710 - accuracy: 0.0020 - tp: 262.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 5652.0000 - precision: 1.0000 - recall: 0.0443 - auc: 0.0000e+00
# Epoch 3/100
# 6/6 [==============================] - 0s 8ms/step - loss: 2.2210 - accuracy: 0.0032 - tp: 3051.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 2863.0000 - precision: 1.0000 - recall: 0.5159 - auc: 0.0000e+00
# Epoch 4/100
# 6/6 [==============================] - 0s 7ms/step - loss: 1.9755 - accuracy: 0.0036 - tp: 5644.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 270.0000 - precision: 1.0000 - recall: 0.9543 - auc: 0.0000e+00
# Epoch 5/100
# 6/6 [==============================] - 0s 14ms/step - loss: 2.0684 - accuracy: 0.0036 - tp: 5825.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 89.0000 - precision: 1.0000 - recall: 0.9850 - auc: 0.0000e+00
# Epoch 6/100
# 6/6 [==============================] - 0s 8ms/step - loss: 1.6005 - accuracy: 0.0036 - tp: 5754.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 160.0000 - precision: 1.0000 - recall: 0.9729 - auc: 0.0000e+00
# Epoch 7/100
# 6/6 [==============================] - 0s 7ms/step - loss: 1.2306 - accuracy: 0.0036 - tp: 5332.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 582.0000 - precision: 1.0000 - recall: 0.9016 - auc: 0.0000e+00
# Epoch 8/100
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1543 - accuracy: 0.0030 - tp: 4357.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 1557.0000 - precision: 1.0000 - recall: 0.7367 - auc: 0.0000e+00
# Epoch 9/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.1681 - accuracy: 0.0030 - tp: 4054.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 1860.0000 - precision: 1.0000 - recall: 0.6855 - auc: 0.0000e+00
# Epoch 10/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.0862 - accuracy: 0.0030 - tp: 4644.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 1270.0000 - precision: 1.0000 - recall: 0.7853 - auc: 0.0000e+00
# Epoch 11/100
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0740 - accuracy: 0.0034 - tp: 5051.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 863.0000 - precision: 1.0000 - recall: 0.8541 - auc: 0.0000e+00
# Epoch 12/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.0497 - accuracy: 0.0034 - tp: 4989.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 925.0000 - precision: 1.0000 - recall: 0.8436 - auc: 0.0000e+00
# Epoch 13/100
# 6/6 [==============================] - 0s 6ms/step - loss: 1.0187 - accuracy: 0.0034 - tp: 4693.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 1221.0000 - precision: 1.0000 - recall: 0.7935 - auc: 0.0000e+00
# Epoch 14/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.
0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 680.0000 - precision: 1.0000 - recall: 0.8850 - auc: 0.0000e+00
# Epoch 77/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5172 - accuracy: 0.0036 - tp: 5253.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 661.0000 - precision: 1.0000 - recall: 0.8882 - auc: 0.0000e+00
# Epoch 78/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5156 - accuracy: 0.0036 - tp: 5251.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 663.0000 - precision: 1.0000 - recall: 0.8879 - auc: 0.0000e+00
# Epoch 79/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5135 - accuracy: 0.0036 - tp: 5244.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 670.0000 - precision: 1.0000 - recall: 0.8867 - auc: 0.0000e+00
# Epoch 80/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5125 - accuracy: 0.0036 - tp: 5245.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 669.0000 - precision: 1.0000 - recall: 0.8869 - auc: 0.0000e+00
# Epoch 81/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5112 - accuracy: 0.0036 - tp: 5258.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 656.0000 - precision: 1.0000 - recall: 0.8891 - auc: 0.0000e+00
# Epoch 82/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5093 - accuracy: 0.0036 - tp: 5257.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 657.0000 - precision: 1.0000 - recall: 0.8889 - auc: 0.0000e+00
# Epoch 83/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5083 - accuracy: 0.0036 - tp: 5257.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 657.0000 - precision: 1.0000 - recall: 0.8889 - auc: 0.0000e+00
# Epoch 84/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5052 - accuracy: 0.0036 - tp: 5263.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 651.0000 - precision: 1.0000 - recall: 0.8899 - auc: 0.0000e+00
# Epoch 85/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5038 - accuracy: 0.0036 - tp: 5266.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 648.0000 - precision: 1.0000 - recall: 0.8904 - auc: 0.0000e+00
# Epoch 86/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4998 - accuracy: 0.0036 - tp: 5269.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 645.0000 - precision: 1.0000 - recall: 0.8909 - auc: 0.0000e+00
# Epoch 87/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4984 - accuracy: 0.0036 - tp: 5266.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 648.0000 - precision: 1.0000 - recall: 0.8904 - auc: 0.0000e+00
# Epoch 88/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4965 - accuracy: 0.0036 - tp: 5259.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 655.0000 - precision: 1.0000 - recall: 0.8892 - auc: 0.0000e+00
# Epoch 89/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4943 - accuracy: 0.0036 - tp: 5266.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 648.0000 - precision: 1.0000 - recall: 0.8904 - auc: 0.0000e+00
# Epoch 90/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4921 - accuracy: 0.0036 - tp: 5264.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 650.0000 - precision: 1.0000 - recall: 0.8901 - auc: 0.0000e+00
# Epoch 91/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4900 - accuracy: 0.0036 - tp: 5250.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 664.0000 - precision: 1.0000 - recall: 0.8877 - auc: 0.0000e+00
# Epoch 92/100
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4880 - accuracy: 0.0036 - tp: 5265.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 649.0000 - precision: 1.0000 - recall: 0.8903 - auc: 0.0000e+00
# Epoch 93/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4860 - accuracy: 0.0036 - tp: 5266.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 648.0000 - precision: 1.0000 - recall: 0.8904 - auc: 0.0000e+00
# Epoch 94/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4841 - accuracy: 0.0036 - tp: 5243.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 671.0000 - precision: 1.0000 - recall: 0.8865 - auc: 0.0000e+00
# Epoch 95/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4816 - accuracy: 0.0036 - tp: 5256.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 658.0000 - precision: 1.0000 - recall: 0.8887 - auc: 0.0000e+00
# Epoch 96/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4800 - accuracy: 0.0036 - tp: 5261.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 653.0000 - precision: 1.0000 - recall: 0.8896 - auc: 0.0000e+00
# Epoch 97/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4776 - accuracy: 0.0036 - tp: 5246.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 668.0000 - precision: 1.0000 - recall: 0.8870 - auc: 0.0000e+00
# Epoch 98/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4751 - accuracy: 0.0036 - tp: 5244.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 670.0000 - precision: 1.0000 - recall: 0.8867 - auc: 0.0000e+00
# Epoch 99/100
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4743 - accuracy: 0.0036 - tp: 5253.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 661.0000 - precision: 1.0000 - recall: 0.8882 - auc: 0.0000e+00
# Epoch 100/100
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4728 - accuracy: 0.0036 - tp: 5257.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 657.0000 - precision: 1.0000 - recall: 0.8889 - auc: 0.0000e+00

# %%
# Make predictions using the testing data X_test
predicted = model.predict(X_test)

# Evaluate the model
model.evaluate(X_test, y_test)
# Out:
# 62/62 [==============================] - 1s 2ms/step - loss: 0.4938 - accuracy: 0.0051 - tp: 1764.0000 - tn: 0.0000e+00 - fp: 0.0000e+00 - fn: 208.0000 - precision: 1.0000 - recall: 0.8945 - auc: 0.0000e+00
# [0.4937787353992462,
#  0.005070994142442942,
#  1764.0,
#  0.0,
#  0.0,
#  208.0,
#  1.0,
#  0.8945233225822449,
#  0.0]

# %%
predicted_OPS = scaler_y.inverse_transform(predicted)

# %%
moneyball = pd.DataFrame({
    "Real": y_test.ravel(),
    "Predicted": predicted_OPS.ravel()
    }, index = stats_df.index[-len(predicted_OPS): ])
moneyball.head(20)
# Out:
#                     Real  Predicted
# Player
# Jose Bautista      0.671   0.791808
# Jose Ramirez       0.586   0.779840
# Lorenzo Cain       0.711   0.802768
# Billy Hamilton     0.286   0.768332
# Kyle Seager        0.865   0.838292
# Ryon Healy         0.510   0.764852
# Maikel Franco      0.801   0.804590
# Andrew Benintendi  0.811   0.835177
# Anthony Rizzo      0.554   0.783709
# Xander Bogaerts    0.744   0.817676
# Carlos Santana     0.849   0.836810
# Andrew McCutchen   0.694   0.817464
# Kole Calhoun       0.617   0.778779
# Wil Myers          0.610   0.797067
# Jed Lowrie         0.382   0.766049
# Khris Davis        0.959   0.857582
# Justin Smoak       0.743   0.814485
# Mark Trumbo        0.623   0.796580
# Joey Votto         0.664   0.808418
# Paul Goldschmidt   0.747   0.804505

# %%
moneyball = moneyball.groupby('Player').mean()
moneyball.head(20)
# Out:
#                        Real  Predicted
# Player
# A.J. Ellis         0.504333   0.788213
# A.J. Jimenez       0.699000   0.797471
# A.J. Pierzynski    0.658667   0.794826
# AJ Pollock         0.684000   0.809152
# Aaron Altherr      0.331000   0.762571
# Aaron Hicks        0.612000   0.799561
# Aaron Hill         0.747667   0.811830
# Aaron Judge        0.637000   0.784056
# Abraham Almonte    0.547800   0.781603
# Adalberto Mondesi  0.721000   0.795159
# Adam Dunn          0.709000   0.816967
# Adam Duvall        0.843000   0.818724
# Adam Eaton         0.665333   0.805146
# Adam Engel         0.225000   0.727529
# Adam Frazier       0.848000   0.828647
# Adam Jones         0.633500   0.790995
# Adam LaRoche       0.709500   0.795621
# Adam Lind          0.615667   0.786143
# Adam Moore         1.010500   0.830208
# Adam Rosales       0.700500   0.811256

# %%
moneyball.plot(figsize=(12,8))

# %%
moneyball.to_csv('Resources/Moneyball.csv')
